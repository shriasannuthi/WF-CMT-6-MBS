# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import joblib

# %%
model=tf.keras.models.load_model('model_e100.h5')

# %%
import joblib

scl=joblib.load('scaler.joblib')
# Out:
# c:\Python10\lib\site-packages\sklearn\base.py:299: UserWarning: Trying to unpickle estimator StandardScaler from version 1.1.3 when using version 1.2.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
df=pd.read_csv('Final_testpool.csv')

# %%
test_pool=df.drop_duplicates(subset='Loan Identifier', keep ='first')
test_pool
# Out:
#     Loan Identifier  Monthly Reporting Period  Channel  \
# 0         122752190                     82021        2
# 7         122237728                     82021        2
# 14        122128365                     82021        2
# 21        122540611                     82021        1
# 28        122540773                     82021        2
# 35        123238143                     82021        1
# 42        122237832                     82021        2
# 49        122540495                     82021        2
# 56        122237736                     82021        2
# 63        122540517                     82021        2
# 70        122540748                     82021        2
# 77        122540664                     82021        2
# 84        122237835                     82021        1
# 91        122540589                     82021        1
# 98        122956092                     82021        2
#
#     Original Interest Rate  Current Interest Rate  Original UPB  \
# 0                    3.000                  3.000        597000
# 7                    2.750                  2.750        243000
# 14                   2.875                  2.875        566000
# 21                   2.250                  2.250        425000
# 28                   2.750                  2.750        167000
# 35                   2.750                  2.750        193000
# 42                   2.750                  2.750        236000
# 49                   2.500                  2.500        180000
# 56                   3.375                  3.375        168000
# 63                   2.750                  2.750        311000
# 70                   3.125                  3.125        174000
# 77                   2.750                  2.750         96000
# 84                   2.750                  2.750        328000
# 91                   2.875                  2.875        353000
# 98                   3.125                  3.125        215000
#
#     Current Actual UPB  Original Loan Term  Origination Date  \
# 0            590000.00                 360             12021
# 7            237000.00                 360             12021
# 14           560000.00                 360             12021
# 21           411019.10                 360            122020
# 28           154316.17                 144            122020
# 35           191000.00                 360             12021
# 42           233268.13                 360            122020
# 49           175000.00                 240             12021
# 56           164722.98                 360             92020
# 63           303149.80                 240            122020
# 70           171000.00                 240             12021
# 77            94546.56                 360            122020
# 84           323366.39                 360            122020
# 91           344206.70                 240            112020
# 98           213000.00                 360             12021
#
#     First Payment Date  ...  Property Valuation Method  \
# 0                32021  ...                          3
# 7                32021  ...                          0
# 14               32021  ...                          3
# 21               22021  ...                          0
# 28               22021  ...                          3
# 35               32021  ...                          3
# 42               22021  ...                          0
# 49               32021  ...                          3
# 56              112020  ...                          0
# 63               22021  ...                          3
# 70               32021  ...                          3
# 77               22021  ...                          3
# 84               22021  ...                          3
# 91               12021  ...                          3
# 98               32021  ...                          0
#
#     High Balance Loan Indicator  Unemployment_rate  Divorce_rate  \
# 0                             1                5.3           2.5
# 7                             0                5.3           2.5
# 14                            1                5.3           2.5
# 21                            0                5.3           2.5
# 28                            0                5.3           2.5
# 35                            0                5.3           2.5
# 42                            0                5.3           2.5
# 49                            0                5.3           2.5
# 56                            0                5.3           2.5
# 63                            0                5.3           2.5
# 70                            0                5.3           2.5
# 77                            0                5.3           2.5
# 84                            0                5.3           2.5
# 91                            0                5.3           2.5
# 98                            0                5.3           2.5
#
#     Inflation_rate          EMI  UPB_diff  Interest_Component  Previous_UPB  \
# 0              5.3  2516.976081   1000.00         1492.500000     591000.00
# 7              5.3   992.026070      0.00          556.875000     237000.00
# 14             5.3  2348.291420   1000.00         1356.041667     561000.00
# 21             5.3  1624.545935    980.90          796.875000     412000.00
# 28             5.3  1362.898181   1683.83          382.708333     156000.00
# 35             5.3   787.905479   1000.00          442.291667     192000.00
# 42             5.3   963.449187    731.87          540.833333     234000.00
# 49             5.3   953.825208   1000.00          375.000000     176000.00
# 56             5.3   742.721633    279.32          472.500000     165002.30
# 63             5.3  1686.137214    850.20          712.708333     304000.00
# 70             5.3   975.924042      0.00          453.125000     171000.00
# 77             5.3   391.911534    453.44          220.000000      95000.00
# 84             5.3  1339.031074   -366.39          751.666667     323000.00
# 91             5.3  1935.714431   1108.39          845.729167     345315.09
# 98             5.3   921.007222      0.00          559.895833     213000.00
#
#     Remaining MFM
# 0             353
# 7             353
# 14            353
# 21            352
# 28            136
# 35            353
# 42            352
# 49            233
# 56            349
# 63            232
# 70            233
# 77            352
# 84            352
# 91            231
# 98            353
#
# [15 rows x 36 columns]

# %%
li4=list(df['Current Actual UPB'])
li4
# Out:
# [590000.0,
#  589119.62,
#  588004.21,
#  586886.01,
#  585765.02,
#  584641.22,
#  583514.61,
#  237000.0,
#  236596.77,
#  234446.08,
#  233991.32,
#  233535.52,
#  233078.68,
#  232620.79,
#  560000.0,
#  559004.06,
#  557995.04,
#  556983.6,
#  555969.74,
#  554953.45,
#  553934.73,
#  411019.1,
#  407994.18,
#  406963.59,
#  401931.07,
#  400889.11,
#  396845.2,
#  395793.7,
#  154316.17,
#  153009.36,
#  153009.36,
#  150386.75,
#  147996.3,
#  146675.01,
#  145350.69,
#  191000.0,
#  190945.41,
#  190219.72,
#  190219.72,
#  189490.7,
#  189124.93,
#  188758.32,
#  233268.13,
#  232838.23,
#  232407.35,
#  231975.48,
#  231542.62,
#  231108.77,
#  230673.92,
#  175000.0,
#  173809.61,
#  172917.88,
#  172024.3,
#  171128.85,
#  170231.54,
#  169332.36,
#  164722.98,
#  164442.87,
#  164161.98,
#  163880.3,
#  163597.82,
#  163314.55,
#  163030.48,
#  303149.8,
#  302158.38,
#  301164.69,
#  300168.72,
#  299170.47,
#  298169.93,
#  297167.1,
#  171000.0,
#  170049.72,
#  169399.71,
#  168748.01,
#  168094.61,
#  167439.51,
#  166782.7,
#  94546.56,
#  94546.56,
#  94371.59,
#  94020.45,
#  93844.27,
#  93667.69,
#  93490.71,
#  323366.39,
#  322750.56,
#  322133.32,
#  321514.66,
#  320273.08,
#  320273.08,
#  319670.05,
#  344206.7,
#  343095.65,
#  341981.94,
#  340865.56,
#  339746.51,
#  338624.78,
#  337500.36,
#  213000.0,
#  212229.84,
#  211724.4,
#  210617.65,
#  209508.01,
#  208895.48,
#  208281.36]

# %%
test_pool=test_pool[test_pool['Original UPB']!=test_pool['Current Actual UPB']]

# %%
test_pool
# Out:
#     Loan Identifier  Monthly Reporting Period  Channel  \
# 0         122752190                     82021        2
# 7         122237728                     82021        2
# 14        122128365                     82021        2
# 21        122540611                     82021        1
# 28        122540773                     82021        2
# 35        123238143                     82021        1
# 42        122237832                     82021        2
# 49        122540495                     82021        2
# 56        122237736                     82021        2
# 63        122540517                     82021        2
# 70        122540748                     82021        2
# 77        122540664                     82021        2
# 84        122237835                     82021        1
# 91        122540589                     82021        1
# 98        122956092                     82021        2
#
#     Original Interest Rate  Current Interest Rate  Original UPB  \
# 0                    3.000                  3.000        597000
# 7                    2.750                  2.750        243000
# 14                   2.875                  2.875        566000
# 21                   2.250                  2.250        425000
# 28                   2.750                  2.750        167000
# 35                   2.750                  2.750        193000
# 42                   2.750                  2.750        236000
# 49                   2.500                  2.500        180000
# 56                   3.375                  3.375        168000
# 63                   2.750                  2.750        311000
# 70                   3.125                  3.125        174000
# 77                   2.750                  2.750         96000
# 84                   2.750                  2.750        328000
# 91                   2.875                  2.875        353000
# 98                   3.125                  3.125        215000
#
#     Current Actual UPB  Original Loan Term  Origination Date  \
# 0            590000.00                 360             12021
# 7            237000.00                 360             12021
# 14           560000.00                 360             12021
# 21           411019.10                 360            122020
# 28           154316.17                 144            122020
# 35           191000.00                 360             12021
# 42           233268.13                 360            122020
# 49           175000.00                 240             12021
# 56           164722.98                 360             92020
# 63           303149.80                 240            122020
# 70           171000.00                 240             12021
# 77            94546.56                 360            122020
# 84           323366.39                 360            122020
# 91           344206.70                 240            112020
# 98           213000.00                 360             12021
#
#     First Payment Date  ...  Property Valuation Method  \
# 0                32021  ...                          3
# 7                32021  ...                          0
# 14               32021  ...                          3
# 21               22021  ...                          0
# 28               22021  ...                          3
# 35               32021  ...                          3
# 42               22021  ...                          0
# 49               32021  ...                          3
# 56              112020  ...                          0
# 63               22021  ...                          3
# 70               32021  ...                          3
# 77               22021  ...                          3
# 84               22021  ...                          3
# 91               12021  ...                          3
# 98               32021  ...                          0
#
#     High Balance Loan Indicator  Unemployment_rate  Divorce_rate  \
# 0                             1                5.3           2.5
# 7                             0                5.3           2.5
# 14                            1                5.3           2.5
# 21                            0                5.3           2.5
# 28                            0                5.3           2.5
# 35                            0                5.3           2.5
# 42                            0                5.3           2.5
# 49                            0                5.3           2.5
# 56                            0                5.3           2.5
# 63                            0                5.3           2.5
# 70                            0                5.3           2.5
# 77                            0                5.3           2.5
# 84                            0                5.3           2.5
# 91                            0                5.3           2.5
# 98                            0                5.3           2.5
#
#     Inflation_rate          EMI  UPB_diff  Interest_Component  Previous_UPB  \
# 0              5.3  2516.976081   1000.00         1492.500000     591000.00
# 7              5.3   992.026070      0.00          556.875000     237000.00
# 14             5.3  2348.291420   1000.00         1356.041667     561000.00
# 21             5.3  1624.545935    980.90          796.875000     412000.00
# 28             5.3  1362.898181   1683.83          382.708333     156000.00
# 35             5.3   787.905479   1000.00          442.291667     192000.00
# 42             5.3   963.449187    731.87          540.833333     234000.00
# 49             5.3   953.825208   1000.00          375.000000     176000.00
# 56             5.3   742.721633    279.32          472.500000     165002.30
# 63             5.3  1686.137214    850.20          712.708333     304000.00
# 70             5.3   975.924042      0.00          453.125000     171000.00
# 77             5.3   391.911534    453.44          220.000000      95000.00
# 84             5.3  1339.031074   -366.39          751.666667     323000.00
# 91             5.3  1935.714431   1108.39          845.729167     345315.09
# 98             5.3   921.007222      0.00          559.895833     213000.00
#
#     Remaining MFM
# 0             353
# 7             353
# 14            353
# 21            352
# 28            136
# 35            353
# 42            352
# 49            233
# 56            349
# 63            232
# 70            233
# 77            352
# 84            352
# 91            231
# 98            353
#
# [15 rows x 36 columns]

# %%
test_pool=test_pool.drop_duplicates(subset=['Loan Identifier'],keep='first')
test_pool.columns
# Out:
# Index(['Loan Identifier', 'Monthly Reporting Period', 'Channel',
#        'Original Interest Rate', 'Current Interest Rate', 'Original UPB',
#        'Current Actual UPB', 'Original Loan Term', 'Origination Date',
#        'First Payment Date', 'Remaining Months To Maturity',
#        'Original Loan to Value Ratio (LTV)', 'Debt-To-Income (DTI)',
#        'Borrower Credit Score at Origination',
#        'First Time Home Buyer Indicator', 'Loan Purpose', 'Property Type',
#        'Number of Units', 'Occupancy Status',
#        'Metropolitan Statistical Area (MSA)', 'Zip Code Short',
#        'Interest Only Loan Indicator', 'Current Loan Delinquency Status',
#        'Modification Flag', 'Zero Balance Code', 'Special Eligibility Program',
#        'Property Valuation Method', 'High Balance Loan Indicator',
#        'Unemployment_rate', 'Divorce_rate', 'Inflation_rate', 'EMI',
#        'UPB_diff', 'Interest_Component', 'Previous_UPB', 'Remaining MFM'],
#       dtype='object')

# %%
test_pool.drop(['Loan Identifier','EMI','UPB_diff','Interest_Component','Remaining Months To Maturity'], axis=1, inplace = True)
test_pool
# Out:
#     Monthly Reporting Period  Channel  Original Interest Rate  \
# 0                      82021        2                   3.000
# 7                      82021        2                   2.750
# 14                     82021        2                   2.875
# 21                     82021        1                   2.250
# 28                     82021        2                   2.750
# 35                     82021        1                   2.750
# 42                     82021        2                   2.750
# 49                     82021        2                   2.500
# 56                     82021        2                   3.375
# 63                     82021        2                   2.750
# 70                     82021        2                   3.125
# 77                     82021        2                   2.750
# 84                     82021        1                   2.750
# 91                     82021        1                   2.875
# 98                     82021        2                   3.125
#
#     Current Interest Rate  Original UPB  Current Actual UPB  \
# 0                   3.000        597000           590000.00
# 7                   2.750        243000           237000.00
# 14                  2.875        566000           560000.00
# 21                  2.250        425000           411019.10
# 28                  2.750        167000           154316.17
# 35                  2.750        193000           191000.00
# 42                  2.750        236000           233268.13
# 49                  2.500        180000           175000.00
# 56                  3.375        168000           164722.98
# 63                  2.750        311000           303149.80
# 70                  3.125        174000           171000.00
# 77                  2.750         96000            94546.56
# 84                  2.750        328000           323366.39
# 91                  2.875        353000           344206.70
# 98                  3.125        215000           213000.00
#
#     Original Loan Term  Origination Date  First Payment Date  \
# 0                  360             12021               32021
# 7                  360             12021               32021
# 14                 360             12021               32021
# 21                 360            122020               22021
# 28                 144            122020               22021
# 35                 360             12021               32021
# 42                 360            122020               22021
# 49                 240             12021               32021
# 56                 360             92020              112020
# 63                 240            122020               22021
# 70                 240             12021               32021
# 77                 360            122020               22021
# 84                 360            122020               22021
# 91                 240            112020               12021
# 98                 360             12021               32021
#
#     Original Loan to Value Ratio (LTV)  ...  Modification Flag  \
# 0                                   75  ...                  0
# 7                                   92  ...                  0
# 14                                  57  ...                  0
# 21                                  94  ...                  0
# 28                                  41  ...                  0
# 35                                  51  ...                  0
# 42                                  75  ...                  0
# 49                                  68  ...                  0
# 56                                  95  ...                  0
# 63                                  64  ...                  0
# 70                                  53  ...                  0
# 77                                  32  ...                  0
# 84                                  77  ...                  0
# 91                                  57  ...                  0
# 98                                  72  ...                  0
#
#     Zero Balance Code  Special Eligibility Program  Property Valuation Method  \
# 0                   0                            0                          3
# 7                   0                            0                          0
# 14                  0                            0                          3
# 21                  0                            0                          0
# 28                  0                            0                          3
# 35                  0                            0                          3
# 42                  0                            0                          0
# 49                  0                            0                          3
# 56                  0                            0                          0
# 63                  0                            0                          3
# 70                  0                            0                          3
# 77                  0                            2                          3
# 84                  0                            0                          3
# 91                  0                            0                          3
# 98                  0                            0                          0
#
#     High Balance Loan Indicator  Unemployment_rate  Divorce_rate  \
# 0                             1                5.3           2.5
# 7                             0                5.3           2.5
# 14                            1                5.3           2.5
# 21                            0                5.3           2.5
# 28                            0                5.3           2.5
# 35                            0                5.3           2.5
# 42                            0                5.3           2.5
# 49                            0                5.3           2.5
# 56                            0                5.3           2.5
# 63                            0                5.3           2.5
# 70                            0                5.3           2.5
# 77                            0                5.3           2.5
# 84                            0                5.3           2.5
# 91                            0                5.3           2.5
# 98                            0                5.3           2.5
#
#     Inflation_rate  Previous_UPB  Remaining MFM
# 0              5.3     591000.00            353
# 7              5.3     237000.00            353
# 14             5.3     561000.00            353
# 21             5.3     412000.00            352
# 28             5.3     156000.00            136
# 35             5.3     192000.00            353
# 42             5.3     234000.00            352
# 49             5.3     176000.00            233
# 56             5.3     165002.30            349
# 63             5.3     304000.00            232
# 70             5.3     171000.00            233
# 77             5.3      95000.00            352
# 84             5.3     323000.00            352
# 91             5.3     345315.09            231
# 98             5.3     213000.00            353
#
# [15 rows x 31 columns]

# %%
test_pool['Modification Flag']=test_pool['Modification Flag'].fillna(2)

# %%
X_test_pool=test_pool.drop(['Current Actual UPB'],axis=1)

# %%
X_test_pool2=X_test_pool

# %%
y_test_pool=test_pool['Current Actual UPB']

# %%
def scale(value, att_index):
    scaled = (value - scl.mean_[att_index])/ scl.scale_[att_index]
    return scaled

# %%
def update(mrp):
    if((mrp//10000)==12):
        mrp = mrp - 110000 + 1
    else:
        mrp += 10000
    return mrp

# %%
Unemploy={"2000":4.0,
     "2001":4.7,
     "2002":5.8,
     "2003":6.0,
     "2004":5.5,
     "2005":5.1,
     "2006":4.6,
     "2007":4.6,
     "2008":5.8,
     "2009":9.3,
     "2010":9.6,
     "2011":8.9,
     "2012":8.1,
     "2013":7.4,
     "2014":6.2,
     "2015":5.3,
     "2016":4.9,
     "2017":4.4,
     "2018":3.9,
     "2019":3.7,
     "2020":8.1,
     "2021":5.3,
     "2022":3.6,
     "2023":3.4
     }

# %%
divorce={"2000":4.0,
     "2001":4.0,
     "2002":3.9,
     "2003":3.8,
     "2004":3.7,
     "2005":3.6,
     "2006":3.7,
     "2007":3.6,
     "2008":3.5,
     "2009":3.5,
     "2010":3.6,
     "2011":3.6,
     "2012":3.4,
     "2013":3.3,
     "2014":3.2,
     "2015":3.1,
     "2016":3.0,
     "2017":2.9,
     "2018":2.9,
     "2019":2.7,
     "2020":2.3,
     "2021":2.5,
     "2022":2.3,
     "2023":2.3
     }

# %%
inflation_data = {
    "12022": 7.5,
    "22022": 7.9,
    "32022": 8.5,
    "42022": 8.3,
    "52022": 8.6,
    "62022": 9.1,
    "72022": 8.5,
    "82022": 8.3,
    "92022": 8.2,
    "102022": 7.7,
    "112022": 7.1,
    "122022": 6.5,
    "12021": 1.4,
    "22021": 1.7,
    "32021": 2.6,
    "42021": 4.2,
    "52021": 5.0,
    "62021": 5.4,
    "72021": 5.4,
    "82021": 5.3,
    "92021": 5.4,
    "102021": 6.2,
    "112021": 6.8,
    "122021": 7.0,
    "12020": 2.5,
    "22020": 2.3,
    "32020": 1.5,
    "42020": 0.3,
    "52020": 0.1,
    "62020": 0.6,
    "72020": 1.0,
    "82020": 1.3,
    "92020": 1.4,
    "102020": 1.2,
    "112020": 1.2,
    "122020": 1.4,
    "12019": 1.6,
    "22019": 1.5,
    "32019": 1.9,
    "42019": 2.0,
    "52019": 1.8,
    "62019": 1.6,
    "72019": 1.8,
    "82019": 1.7,
    "92019": 1.7,
    "102019": 1.8,
    "112019": 2.1,
    "122019": 2.3,
    "12018": 2.1,
    "22018": 2.2,
    "32018": 2.4,
    "42018": 2.5,
    "52018": 2.8,
    "62018": 2.9,
    "72018": 2.9,
    "82018": 2.7,
    "92018": 2.3,
    "102018": 2.5,
    "112018": 2.2,
    "122018": 1.9,
    "12017": 2.5,
    "22017": 2.7,
    "32017": 2.4,
    "42017": 2.2,
    "52017": 1.9,
    "62017": 1.6,
    "72017": 1.7,
    "82017": 1.9,
    "92017": 2.2,
    "102017": 2.0,
    "112017": 2.2,
    "122017": 2.1,
    "12016": 1.4,
    "22016": 1.0,
    "32016": 0.9,
    "42016": 1.1,
    "52016": 1.0,
    "62016": 1.0,
    "72016": 0.8,
    "82016": 1.1,
    "92016": 1.5,
    "102016": 1.6,
    "112016": 1.7,
    "122016": 2.1,
    "12015": -0.1,
    "22015": 0.0,
    "32015": -0.1,
    "42015": -0.2,
    "52015": 0.0,
    "62015": 0.1,
    "72015": 0.2,
    "82015": 0.2,
    "92015": 0.0,
    "102015": 0.2,
    "112015": 0.5,
    "122015": 0.7,
    "12014": 1.6,
    "22014": 1.1,
    "32014": 1.5,
    "42014": 2.0,
    "52014": 2.1,
    "62014": 2.1,
    "72014": 2.0,
    "82014": 1.7,
    "92014": 1.7,
    "102014": 1.7,
    "112014": 1.3,
    "122014": 0.8,
    "12013": 1.6,
    "22013": 2.0,
    "32013": 1.5,
    "42013": 1.1,
    "52013": 1.4,
    "62013": 1.8,
    "72013": 2.0,
    "82013": 1.5,
    "92013": 1.2,
    "102013": 1.0,
    "112013": 1.2,
    "122013": 1.5,
    "12012": 2.9,
    "22012": 2.9,
    "32012": 2.7,
    "42012": 2.3,
    "52012": 1.7,
    "62012": 1.7,
    "72012": 1.4,
    "82012": 1.7,
    "92012": 2.0,
    "102012": 2.2,
    "112012": 1.8,
    "122012": 1.7,
    "12011": 1.6,
    "22011": 2.1,
    "32011": 2.7,
    "42011": 3.2,
    "52011": 3.6,
    "62011": 3.6,
    "72011": 3.6,
    "82011": 3.8,
    "92011": 3.9,
    "102011": 3.5,
    "112011": 3.4,
    "122011": 3.0,
    "12010": 2.6,
    "22010": 2.1,
    "32010": 2.3,
    "42010": 2.2,
    "52010": 2.0,
    "62010": 1.1,
    "72010": 1.2,
    "82010": 1.1,
    "92010": 1.1,
    "102010": 1.2,
    "112010": 1.1,
    "122010": 1.5,
    "12009": 0.0,
    "22009": 0.2,
    "32009": -0.4,
    "42009": -0.7,
    "52009": -1.3,
    "62009": -1.4,
    "72009": -2.1,
    "82009": -1.5,
    "92009": -1.3,
    "102009": -0.2,
    "112009": 1.8,
    "122009": 2.7,
    "12008": 4.3,
    "22008": 4.0,
    "32008": 4.0,
    "42008": 3.9,
    "52008": 4.2,
    "62008": 5.0,
    "72008": 5.6,
    "82008": 5.4,
    "92008": 4.9,
    "102008": 3.7,
    "112008": 1.1,
    "122008": 0.1,
    "12007": 2.1,
    "22007": 2.4,
    "32007": 2.8,
    "42007": 2.6,
    "52007": 2.7,
    "62007": 2.7,
    "72007": 2.4,
    "82007": 2.0,
    "92007": 2.8,
    "102007": 3.5,
    "112007": 4.3,
    "122007": 4.1,
    "12006": 4.0,
    "22006": 3.6,
    "32006": 3.4,
    "42006": 3.5,
    "52006": 4.2,
    "62006": 4.3,
    "72006": 4.1,
    "82006": 3.8,
    "92006": 2.1,
    "102006": 1.3,
    "112006": 2.0,
    "122006": 2.5,
    "12005": 3.0,
    "22005": 3.0,
    "32005": 3.1,
    "42005": 3.5,
    "52005": 2.8,
    "62005": 2.5,
    "72005": 3.2,
    "82005": 3.6,
    "92005": 4.7,
    "102005": 4.3,
    "112005": 3.5,
    "122005": 3.4,
    "12004": 1.9,
    "22004": 1.7,
    "32004": 1.7,
    "42004": 2.3,
    "52004": 3.1,
    "62004": 3.3,
    "72004": 3.0,
    "82004": 2.7,
    "92004": 2.5,
    "102004": 3.2,
    "112004": 3.5,
    "122004": 3.3,
    "12003": 2.6, 
    "22003": 3.0, 
    "32003": 3.0, 
    "42003": 2.2, 
    "52003": 2.1, 
    "62003": 2.1,
    "72003": 2.1, 
    "82003": 2.2, 
    "92003": 2.3, 
    "102003": 2.0, 
    "112003": 1.8, 
    "122003": 1.9,
    "12002": 1.1, 
    "22002": 1.1, 
    "32002": 1.5, 
    "42002": 1.6, 
    "52002": 1.2, 
    "62002": 1.1,
    "72002": 1.5, 
    "82002": 1.8, 
    "92002": 1.5, 
    "102002": 2.0, 
    "112002": 2.2, 
    "122002": 2.4,
    "12001": 3.7, 
    "22001": 3.5, 
    "32001": 2.9, 
    "42001": 3.3, 
    "52001": 3.6, 
    "62001": 3.2,
    "72001": 2.7, 
    "82001": 2.7, 
    "92001": 2.6, 
    "102001": 2.1, 
    "112001": 1.9, 
    "122001": 1.6,
    "12000": 2.7, 
    "22000": 3.2, 
    "32000": 3.8, 
    "42000": 3.1, 
    "52000": 3.2, 
    "62000": 3.7,
    "72000": 3.7, 
    "82000": 3.4, 
    "92000": 3.5, 
    "102000": 3.4, 
    "112000": 3.4, 
    "122000": 3.4,
    "12023": 6.4,
    "22023": 6.0,
    "32023": 5.0,
    "42023": 4.9
}

# %%
li2=[]

def dnn_forecast(test_pool): 
    for i in range(len(test_pool)):
        testing_x=test_pool[i:i+1]
        test_unscaled=testing_x
        testing_x=scl.transform(testing_x)

        fore=[]

        p=testing_x[0]
        pre=p[28]
        single_entry = np.expand_dims(p, axis=0)

        for i in range(7): 
            g=model.predict(single_entry)
            fore.append(g[0][0])

            print(g[0][0])

            test_unscaled['Previous_UPB']=g[0][0]
            test_unscaled['Monthly Reporting Period']=update(int(test_unscaled['Monthly Reporting Period']))
            k=str(int(test_unscaled['Monthly Reporting Period']))
            k=k[::-1]
            r=k[:4]

            r=r[::-1]
            print(r)

            if(k=="52023"):
                print("done")
                break
            
            test_unscaled['Unemployment_rate']=Unemploy[r]
            test_unscaled['Divorce_rate']=divorce[r]
            test_unscaled['Inflation_rate']=inflation_data[str(int(test_unscaled['Monthly Reporting Period']))]
            test_unscaled['Remaining MFM']=int(test_unscaled['Remaining MFM'])-1

            test_scaled=(scl.transform(test_unscaled))[0]
            single_entry = np.expand_dims(test_scaled, axis=0)

        li2.append(fore)

# %%
dnn_forecast(X_test_pool)
# Out:
# 1/1 [==============================] - 0s 105ms/step
# 590309.56
# 2021
# 1/1 [==============================] - 0s 39ms/step
# 589616.4
# 2021
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Previous_UPB']=g[0][0]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Monthly Reporting Period']=update(int(test_unscaled['Monthly Reporting Period']))
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Unemployment_rate']=Unemploy[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Divorce_rate']=divorce[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Inflation_rate']=inflation_data[str(int(test_unscaled['Monthly Reporting Period']))]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Remaining MFM']=int(test_unscaled['Remaining MFM'])-1
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Previous_UPB']=g[0][0]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Monthly Reporting Period']=update(int(test_unscaled['Monthly Reporting Period']))
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Unemployment_rate']=Unemploy[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Divorce_rate']=divorce[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Inflation_rate']=inflation_data[str(int(test_unscaled['Monthly Reporting Period']))]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Remaining MFM']=int(test_unscaled['Remaining MFM'])-1
# 1/1 [==============================] - 0s 78ms/step
# 588922.75
# 2021
# 1/1 [==============================] - 0s 59ms/step
# 588228.0
# 2021
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Previous_UPB']=g[0][0]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Monthly Reporting Period']=update(int(test_unscaled['Monthly Reporting Period']))
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Unemployment_rate']=Unemploy[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Divorce_rate']=divorce[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Inflation_rate']=inflation_data[str(int(test_unscaled['Monthly Reporting Period']))]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Remaining MFM']=int(test_unscaled['Remaining MFM'])-1
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Previous_UPB']=g[0][0]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Monthly Reporting Period']=update(int(test_unscaled['Monthly Reporting Period']))
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Unemployment_rate']=Unemploy[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Divorce_rate']=divorce[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Inflation_rate']=inflation_data[str(int(test_unscaled['Monthly Reporting Period']))]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Remaining MFM']=int(test_unscaled['Remaining MFM'])-1
# 1/1 [==============================] - 0s 48ms/step
# 587530.9
# 2022
# 1/1 [==============================] - 0s 53ms/step
# 586849.4
# 2022
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Previous_UPB']=g[0][0]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Monthly Reporting Period']=update(int(test_unscaled['Monthly Reporting Period']))
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Unemployment_rate']=Unemploy[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Divorce_rate']=divorce[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Inflation_rate']=inflation_data[str(int(test_unscaled['Monthly Reporting Period']))]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Remaining MFM']=int(test_unscaled['Remaining MFM'])-1
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Previous_UPB']=g[0][0]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Monthly Reporting Period']=update(int(test_unscaled['Monthly Reporting Period']))
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Unemployment_rate']=Unemploy[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Divorce_rate']=divorce[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Inflation_rate']=inflation_data[str(int(test_unscaled['Monthly Reporting Period']))]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Remaining MFM']=int(test_unscaled['Remaining MFM'])-1
# 1/1 [==============================] - 0s 59ms/step
# 586169.0
# 2022
# 1/1 [==============================] - 0s 59ms/step
# 236528.52
# 2021
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Previous_UPB']=g[0][0]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Monthly Reporting Period']=update(int(test_unscaled['Monthly Reporting Period']))
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Unemployment_rate']=Unemploy[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Divorce_rate']=divorce[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Inflation_rate']=inflation_data[str(int(test_unscaled['Monthly Reporting Period']))]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Remaining MFM']=int(test_unscaled['Remaining MFM'])-1
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Previous_UPB']=g[0][0]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Monthly Reporting Period']=update(int(test_unscaled['Monthly Reporting Period']))
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Unemployment_rate']=Unemploy[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Divorce_rate']=divorce[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Inflation_rate']=inflation_data[str(int(test_unscaled['Monthly Reporting Period']))]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Remaining MFM']=int(test_unscaled['Remaining MFM'])-1
# 1/1 [==============================] - 0s 51ms/step
# 236061.89
# 2021
# 1/1 [==============================] - 0s 79ms/step
# 235609.9
# 2021
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Previous_UPB']=g[0][0]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Monthly Reporting Period']=update(int(test_unscaled['Monthly Reporting Period']))
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Unemployment_rate']=Unemploy[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Divorce_rate']=divorce[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Inflation_rate']=inflation_data[str(int(test_unscaled['Monthly Reporting Period']))]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Remaining MFM']=int(test_unscaled['Remaining MFM'])-1
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Previous_UPB']=g[0][0]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Monthly Reporting Period']=update(int(test_unscaled['Monthly Reporting Period']))
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Unemployment_rate']=Unemploy[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Divorce_rate']=divorce[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Inflation_rate']=inflation_data[str(int(test_unscaled['Monthly Reporting Period']))]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Remaining MFM']=int(test_unscaled['Remaining MFM'])-1
# 1/1 [==============================] - 0s 70ms/step
# 235170.47
# 2021
# 1/1 [==============================] - 0s 34ms/step
# 234738.52
# 2022
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Previous_UPB']=g[0][0]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Monthly Reporting Period']=update(int(test_unscaled['Monthly Reporting Period']))
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Unemployment_rate']=Unemploy[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Divorce_rate']=divorce[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Inflation_rate']=inflation_data[str(int(test_unscaled['Monthly Reporting Period']))]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Remaining MFM']=int(test_unscaled['Remaining MFM'])-1
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Previous_UPB']=g[0][0]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Monthly Reporting Period']=update(int(test_unscaled['Monthly Reporting Period']))
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Unemployment_rate']=Unemploy[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Divorce_rate']=divorce[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Inflation_rate']=inflation_data[str(int(test_unscaled['Monthly Reporting Period']))]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Remaining MFM']=int(test_unscaled['Remaining MFM'])-1
# 1/1 [==============================] - 0s 41ms/step
# 234308.02
# 2022
# 1/1 [==============================] - 0s 30ms/step
# 233886.56
# 2022
# 1/1 [==============================] - 0s 31ms/step
# 560344.0
# 2021
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Previous_UPB']=g[0][0]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Monthly Reporting Period']=update(int(test_unscaled['Monthly Reporting Period']))
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Unemployment_rate']=Unemploy[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Divorce_rate']=divorce[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Inflation_rate']=inflation_data[str(int(test_unscaled['Monthly Reporting Period']))]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Remaining MFM']=int(test_unscaled['Remaining MFM'])-1
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Previous_UPB']=g[0][0]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Monthly Reporting Period']=update(int(test_unscaled['Monthly Reporting Period']))
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Unemployment_rate']=Unemploy[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Divorce_rate']=divorce[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Inflation_rate']=inflation_data[str(int(test_unscaled['Monthly Reporting Period']))]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Remaining MFM']=int(test_unscaled['Remaining MFM'])-1
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Previous_UPB']=g[0][0]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Monthly Reporting Period']=update(int(test_unscaled['Monthly Reporting Period']))
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Unemployment_rate']=Unemploy[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Divorce_rate']=divorce[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Inflation_rate']=inflation_data[str(int(test_unscaled['Monthly Reporting Period']))]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Remaining MFM']=int(test_unscaled['Remaining MFM'])-1
# 1/1 [==============================] - 0s 31ms/step
# 559686.6
# 2021
# 1/1 [==============================] - 0s 29ms/step
# 559033.1
# 2021
# 1/1 [==============================] - 0s 31ms/step
# 558381.9
# 2021
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Previous_UPB']=g[0][0]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Monthly Reporting Period']=update(int(test_unscaled['Monthly Reporting Period']))
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Unemployment_rate']=Unemploy[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Divorce_rate']=divorce[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Inflation_rate']=inflation_data[str(int(test_unscaled['Monthly Reporting Period']))]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Remaining MFM']=int(test_unscaled['Remaining MFM'])-1
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Previous_UPB']=g[0][0]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Monthly Reporting Period']=update(int(test_unscaled['Monthly Reporting Period']))
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Unemployment_rate']=Unemploy[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Divorce_rate']=divorce[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Inflation_rate']=inflation_data[str(int(test_unscaled['Monthly Reporting Period']))]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Remaining MFM']=int(test_unscaled['Remaining MFM'])-1
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Previous_UPB']=g[0][0]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Monthly Reporting Period']=update(int(test_unscaled['Monthly Reporting Period']))
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Unemployment_rate']=Unemploy[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Divorce_rate']=divorce[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Inflation_rate']=inflation_data[str(int(test_unscaled['Monthly Reporting Period']))]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Remaining MFM']=int(test_unscaled['Remaining MFM'])-1
# 1/1 [==============================] - 0s 33ms/step
# 557728.4
# 2022
# 1/1 [==============================] - 0s 34ms/step
# 557088.7
# 2022
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Previous_UPB']=g[0][0]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Monthly Reporting Period']=update(int(test_unscaled['Monthly Reporting Period']))
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:34: SettingWithCopyWarning:
# ...
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Remaining MFM']=int(test_unscaled['Remaining MFM'])-1
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Previous_UPB']=g[0][0]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Monthly Reporting Period']=update(int(test_unscaled['Monthly Reporting Period']))
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Unemployment_rate']=Unemploy[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Divorce_rate']=divorce[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Inflation_rate']=inflation_data[str(int(test_unscaled['Monthly Reporting Period']))]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Remaining MFM']=int(test_unscaled['Remaining MFM'])-1
# 1/1 [==============================] - 0s 34ms/step
# 212115.19
# 2021
# 1/1 [==============================] - 0s 31ms/step
# 211832.86
# 2021
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Previous_UPB']=g[0][0]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Monthly Reporting Period']=update(int(test_unscaled['Monthly Reporting Period']))
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Unemployment_rate']=Unemploy[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Divorce_rate']=divorce[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Inflation_rate']=inflation_data[str(int(test_unscaled['Monthly Reporting Period']))]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Remaining MFM']=int(test_unscaled['Remaining MFM'])-1
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Previous_UPB']=g[0][0]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Monthly Reporting Period']=update(int(test_unscaled['Monthly Reporting Period']))
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Unemployment_rate']=Unemploy[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Divorce_rate']=divorce[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Inflation_rate']=inflation_data[str(int(test_unscaled['Monthly Reporting Period']))]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Remaining MFM']=int(test_unscaled['Remaining MFM'])-1
# 1/1 [==============================] - 0s 44ms/step
# 211548.1
# 2022
# 1/1 [==============================] - 0s 36ms/step
# 211253.42
# 2022
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Previous_UPB']=g[0][0]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Monthly Reporting Period']=update(int(test_unscaled['Monthly Reporting Period']))
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Unemployment_rate']=Unemploy[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Divorce_rate']=divorce[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Inflation_rate']=inflation_data[str(int(test_unscaled['Monthly Reporting Period']))]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Remaining MFM']=int(test_unscaled['Remaining MFM'])-1
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Previous_UPB']=g[0][0]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Monthly Reporting Period']=update(int(test_unscaled['Monthly Reporting Period']))
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Unemployment_rate']=Unemploy[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Divorce_rate']=divorce[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Inflation_rate']=inflation_data[str(int(test_unscaled['Monthly Reporting Period']))]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Remaining MFM']=int(test_unscaled['Remaining MFM'])-1
# 1/1 [==============================] - 0s 59ms/step
# 210960.66
# 2022
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Previous_UPB']=g[0][0]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Monthly Reporting Period']=update(int(test_unscaled['Monthly Reporting Period']))
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Unemployment_rate']=Unemploy[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Divorce_rate']=divorce[r]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Inflation_rate']=inflation_data[str(int(test_unscaled['Monthly Reporting Period']))]
# C:\Users\abhis\AppData\Local\Temp\ipykernel_32536\1578703604.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unscaled['Remaining MFM']=int(test_unscaled['Remaining MFM'])-1

# %%
li2
# Out:
# [[590309.56, 589616.4, 588922.75, 588228.0, 587530.9, 586849.4, 586169.0],
#  [236528.52, 236061.89, 235609.9, 235170.47, 234738.52, 234308.02, 233886.56],
#  [560344.0, 559686.6, 559033.1, 558381.9, 557728.4, 557088.7, 556452.6],
#  [411196.66, 410392.9, 409597.44, 408807.94, 408019.5, 406875.56, 405867.75],
#  [154775.27, 153543.03, 152315.22, 151088.88, 149856.92, 148583.14, 147360.64],
#  [191593.52, 191192.23, 190806.11, 190432.73, 190066.86, 189681.72, 189304.25],
#  [233612.52, 233230.36, 232864.2, 232509.78, 232157.47, 231586.66, 231150.23],
#  [175428.81, 174866.12, 174324.48, 173800.73, 173288.06, 172778.78, 172282.03],
#  [164825.12, 164647.42, 164473.08, 164301.0, 164128.94, 163954.11, 163780.4],
#  [302975.66, 301948.84, 300932.38, 299922.78, 298912.8, 297748.3, 296655.94],
#  [170516.64, 170043.28, 169592.53, 169161.25, 168742.72, 168329.3, 167930.06],
#  [94532.52, 94059.14, 93586.586, 93118.26, 92650.61, 92091.195, 91585.625],
#  [322363.44, 321728.97, 321107.34, 320496.4, 319889.28, 319086.8, 318408.03],
#  [344170.0, 343019.4, 341870.6, 340721.47, 339567.88, 338343.62, 337187.8],
#  [212699.11, 212402.16, 212115.19, 211832.86, 211548.1, 211253.42, 210960.66]]

# %%
li4
# Out:
# [590000.0,
#  589119.62,
#  588004.21,
#  586886.01,
#  585765.02,
#  584641.22,
#  583514.61,
#  237000.0,
#  236596.77,
#  234446.08,
#  233991.32,
#  233535.52,
#  233078.68,
#  232620.79,
#  560000.0,
#  559004.06,
#  557995.04,
#  556983.6,
#  555969.74,
#  554953.45,
#  553934.73,
#  411019.1,
#  407994.18,
#  406963.59,
#  401931.07,
#  400889.11,
#  396845.2,
#  395793.7,
#  154316.17,
#  153009.36,
#  153009.36,
#  150386.75,
#  147996.3,
#  146675.01,
#  145350.69,
#  191000.0,
#  190945.41,
#  190219.72,
#  190219.72,
#  189490.7,
#  189124.93,
#  188758.32,
#  233268.13,
#  232838.23,
#  232407.35,
#  231975.48,
#  231542.62,
#  231108.77,
#  230673.92,
#  175000.0,
#  173809.61,
#  172917.88,
#  172024.3,
#  171128.85,
#  170231.54,
#  169332.36,
#  164722.98,
#  164442.87,
#  164161.98,
#  163880.3,
#  163597.82,
#  163314.55,
#  163030.48,
#  303149.8,
#  302158.38,
#  301164.69,
#  300168.72,
#  299170.47,
#  298169.93,
#  297167.1,
#  171000.0,
#  170049.72,
#  169399.71,
#  168748.01,
#  168094.61,
#  167439.51,
#  166782.7,
#  94546.56,
#  94546.56,
#  94371.59,
#  94020.45,
#  93844.27,
#  93667.69,
#  93490.71,
#  323366.39,
#  322750.56,
#  322133.32,
#  321514.66,
#  320273.08,
#  320273.08,
#  319670.05,
#  344206.7,
#  343095.65,
#  341981.94,
#  340865.56,
#  339746.51,
#  338624.78,
#  337500.36,
#  213000.0,
#  212229.84,
#  211724.4,
#  210617.65,
#  209508.01,
#  208895.48,
#  208281.36]

# %%
li3=[]

for i in li2:
    li3=li3+i

# %%
li3
# Out:
# [590309.56,
#  589616.4,
#  588922.75,
#  588228.0,
#  587530.9,
#  586849.4,
#  586169.0,
#  236528.52,
#  236061.89,
#  235609.9,
#  235170.47,
#  234738.52,
#  234308.02,
#  233886.56,
#  560344.0,
#  559686.6,
#  559033.1,
#  558381.9,
#  557728.4,
#  557088.7,
#  556452.6,
#  411196.66,
#  410392.9,
#  409597.44,
#  408807.94,
#  408019.5,
#  406875.56,
#  405867.75,
#  154775.27,
#  153543.03,
#  152315.22,
#  151088.88,
#  149856.92,
#  148583.14,
#  147360.64,
#  191593.52,
#  191192.23,
#  190806.11,
#  190432.73,
#  190066.86,
#  189681.72,
#  189304.25,
#  233612.52,
#  233230.36,
#  232864.2,
#  232509.78,
#  232157.47,
#  231586.66,
#  231150.23,
#  175428.81,
#  174866.12,
#  174324.48,
#  173800.73,
#  173288.06,
#  172778.78,
#  172282.03,
#  164825.12,
#  164647.42,
#  164473.08,
#  164301.0,
#  164128.94,
#  163954.11,
#  163780.4,
#  302975.66,
#  301948.84,
#  300932.38,
#  299922.78,
#  298912.8,
#  297748.3,
#  296655.94,
#  170516.64,
#  170043.28,
#  169592.53,
#  169161.25,
#  168742.72,
#  168329.3,
#  167930.06,
#  94532.52,
#  94059.14,
#  93586.586,
#  93118.26,
#  92650.61,
#  92091.195,
#  91585.625,
#  322363.44,
#  321728.97,
#  321107.34,
#  320496.4,
#  319889.28,
#  319086.8,
#  318408.03,
#  344170.0,
#  343019.4,
#  341870.6,
#  340721.47,
#  339567.88,
#  338343.62,
#  337187.8,
#  212699.11,
#  212402.16,
#  212115.19,
#  211832.86,
#  211548.1,
#  211253.42,
#  210960.66]

# %%
li3
# Out:
# 105

# %%
li4=np.asarray(li4)
li3=np.asarray(li3)
li5=abs(li4-li3)
li5.mean()
# Out:
# 1199.0603154761905

# %%
len(li4[0:31])
# Out:
# 31

# %%
test_pool[0:5]
# Out:
#     Monthly Reporting Period  Channel  Original Interest Rate  \
# 0                      82021        2                   3.000
# 7                      82021        2                   2.750
# 14                     82021        2                   2.875
# 21                     82021        1                   2.250
# 28                     82021        2                   2.750
#
#     Current Interest Rate  Original UPB  Current Actual UPB  \
# 0                   3.000        597000           590000.00
# 7                   2.750        243000           237000.00
# 14                  2.875        566000           560000.00
# 21                  2.250        425000           411019.10
# 28                  2.750        167000           154316.17
#
#     Original Loan Term  Origination Date  First Payment Date  \
# 0                  360             12021               32021
# 7                  360             12021               32021
# 14                 360             12021               32021
# 21                 360            122020               22021
# 28                 144            122020               22021
#
#     Original Loan to Value Ratio (LTV)  ...  Modification Flag  \
# 0                                   75  ...                  0
# 7                                   92  ...                  0
# 14                                  57  ...                  0
# 21                                  94  ...                  0
# 28                                  41  ...                  0
#
#     Zero Balance Code  Special Eligibility Program  Property Valuation Method  \
# 0                   0                            0                          3
# 7                   0                            0                          0
# 14                  0                            0                          3
# 21                  0                            0                          0
# 28                  0                            0                          3
#
#     High Balance Loan Indicator  Unemployment_rate  Divorce_rate  \
# 0                             1                5.3           2.5
# 7                             0                5.3           2.5
# 14                            1                5.3           2.5
# 21                            0                5.3           2.5
# 28                            0                5.3           2.5
#
#     Inflation_rate  Previous_UPB  Remaining MFM
# 0              5.3      591000.0            353
# 7              5.3      237000.0            353
# 14             5.3      561000.0            353
# 21             5.3      412000.0            352
# 28             5.3      156000.0            136
#
# [5 rows x 31 columns]

# %%
(testing_x)
# Out:
# array([[-1.02954984,  0.84383406, -1.55350925, -1.31814191,  3.66609448,
#          0.60030419, -1.61128169, -1.01986277,  0.19222231,  0.34209664,
#          0.81302176, -0.42491108,  1.32517563,  0.48097901, -0.15472204,
#          0.08211211, -0.53040637,  0.90130701, -0.39673819, -0.12827818,
#         -0.1805408 , -0.11415215, -0.16041107, -0.15799407,  9.77825071,
#         -0.33494945, -1.22110499,  0.08337639,  3.88398382,  0.96277591]])

# %%
testing_x[0]
# Out:
# array([-1.02954984,  0.84383406, -1.55350925, -1.31814191,  3.66609448,
#         0.60030419, -1.61128169, -1.01986277,  0.19222231,  0.34209664,
#         0.81302176, -0.42491108,  1.32517563,  0.48097901, -0.15472204,
#         0.08211211, -0.53040637,  0.90130701, -0.39673819, -0.12827818,
#        -0.1805408 , -0.11415215, -0.16041107, -0.15799407,  9.77825071,
#        -0.33494945, -1.22110499,  0.08337639,  3.88398382,  0.96277591])

# %%
fore=[]

p=testing_x[0]
pre=p[28]
single_entry = np.expand_dims(p, axis=0)

# %%
for i in range(6): 
    # print(i)   
    g=model.predict(single_entry)
    fore.append(g[0][0])

    print(g[0][0])

    test_unscaled['Previous_UPB']=g[0][0]
    test_unscaled['Monthly Reporting Period']=update(int(test_unscaled['Monthly Reporting Period']))
    k=str(int(test_unscaled['Monthly Reporting Period']))
    k=k[::-1]
    r=k[:4]

    r=r[::-1]
    print(r)

    if(k=="52023"):
        print("done")
        break
    
    test_unscaled['Unemployment_rate']=Unemploy[r]
    test_unscaled['Divorce_rate']=divorce[r]
    test_unscaled['Inflation_rate']=inflation_data[str(int(test_unscaled['Monthly Reporting Period']))]
    test_unscaled['Remaining MFM']=int(test_unscaled['Remaining MFM'])-1

    # l=single_entry[0]
    # l[-1]=scale(l[-1]-1,29)
    # print(l[0])
    # l[0]=update(l[0])
    # print(l[0])
    
    # print(k)
    # l[25]=Unemploy[r]
    # l[25]=scale(l[25],25)
    # # l[-1]=(l[-1]-1-270.868240)/90.489321
    # # l[0]=(update(l[0])-67492.295858)/34497.797429	
    # l[28]=scale(g, scl.mean_[28], scl.scale_[28])
    # l[0]=scale(l[0],0)

    # print(test_unscaled)
    
    test_scaled=(scl.transform(test_unscaled))[0]
    single_entry = np.expand_dims(test_scaled, axis=0)
# Out:
# 1/1 [==============================] - 0s 25ms/step
# 596653.2
# 2021
# 1/1 [==============================] - 0s 23ms/step
# 596030.1
# 2021
# 1/1 [==============================] - 0s 28ms/step
# 595358.56
# 2021
# 1/1 [==============================] - 0s 25ms/step
# 594685.25
# 2021
# 1/1 [==============================] - 0s 28ms/step
# 594009.0
# 2021
# 1/1 [==============================] - 0s 57ms/step
# 593329.4
# 2021

# %%
fore
# Out:
# [596653.2, 596030.1, 595358.56, 594685.25, 594009.0, 593329.4]

# %%
# def update(mrp):
#     new_mrp = int(mrp)
#     if((new_mrp//10000)==12):
#         new_mrp = new_mrp - 110000 + 1
#     else:
#         new_mrp += 10000
#     return new_mrp
# print(update('122002'))

# %%
test1_y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[216], line 1
# ----> 1 test1_y
#
# NameError: name 'test1_y' is not defined

# %%
for i in range(len(fore)):
    print(fore[i]-test1_y[i])
# Out:
# -346.8125
# 30.125
# 358.5625
# 685.25
# 2009.0
# 2329.375

# %%
# X_train_1.describe()
# Out:
#        Monthly Reporting Period        Channel  Original Interest Rate  \
# count             804139.000000  804139.000000           804139.000000
# mean               67492.295858       1.398669                5.112216
# std                34497.797429       0.713811                1.361030
# min                12000.000000       0.000000                1.750000
# 25%                42002.000000       1.000000                4.000000
# 50%                72003.000000       2.000000                4.875000
# 75%               102002.000000       2.000000                6.125000
# max               122022.000000       2.000000                9.875000
#
#        Current Interest Rate   Original UPB  Original Loan Term  \
# count          804139.000000  804139.000000       804139.000000
# mean                4.983585  187677.681346          312.137781
# std                 1.504040  111821.292224           79.729861
# min                 0.000000   10000.000000           96.000000
# 25%                 4.000000  104000.000000          240.000000
# 50%                 4.875000  161000.000000          360.000000
# 75%                 6.000000  248000.000000          360.000000
# max                 9.875000  813000.000000          360.000000
#
#        Origination Date  First Payment Date  \
# count     804139.000000       804139.000000
# mean       67319.894812        66955.339365
# std        34307.612765        34256.668292
# min        11999.000000        12000.000000
# 25%        42001.000000        42001.000000
# 50%        62020.000000        72000.000000
# 75%       102000.000000        92019.000000
# max       122020.000000       122020.000000
#
#        Original Loan to Value Ratio (LTV)  Debt-To-Income (DTI)  ...  \
# count                       804139.000000         804139.000000  ...
# mean                            71.578742             34.126307  ...
# std                             17.715732             11.308050  ...
# min                              5.000000              1.000000  ...
# 25%                             62.000000             26.000000  ...
# 50%                             76.000000             35.000000  ...
# 75%                             80.000000             42.000000  ...
# max                             97.000000             64.000000  ...
#
#        Modification Flag  Zero Balance Code  Special Eligibility Program  \
# count      804139.000000      804139.000000                804139.000000
# mean            0.051592           0.018257                     0.046860
# std             0.287244           0.160058                     0.292056
# min             0.000000           0.000000                     0.000000
# 25%             0.000000           0.000000                     0.000000
# 50%             0.000000           0.000000                     0.000000
# 75%             0.000000           0.000000                     0.000000
# max             2.000000           7.000000                     2.000000
#
#        Property Valuation Method  High Balance Loan Indicator  \
# count              804139.000000                804139.000000
# mean                    3.242918                     0.010346
# std                     1.543653                     0.101190
# min                     0.000000                     0.000000
# 25%                     4.000000                     0.000000
# 50%                     4.000000                     0.000000
# 75%                     4.000000                     0.000000
# max                     4.000000                     1.000000
#
#        Unemployment_rate   Divorce_rate  Inflation_rate   Previous_UPB  \
# count       804139.00000  804139.000000   804139.000000  804139.000000
# mean             5.93966       3.128324        2.439492  170358.980081
# std              1.90471       0.514733        1.920493  110003.999783
# min              3.60000       2.300000       -2.100000       0.000000
# 25%              4.40000       2.700000        1.400000   88485.830000
# 50%              5.30000       3.200000        2.100000  145000.000000
# 75%              8.10000       3.600000        3.000000  227768.860000
# max              9.60000       4.000000        9.100000  813000.000000
#
#        Remaining MFM
# count  804139.000000
# mean      270.868240
# std        90.489321
# min       -62.000000
# 25%       191.000000
# 50%       314.000000
# 75%       342.000000
# max       360.000000
#
# [8 rows x 30 columns]

# %%
test1=pd.read_csv('test1.csv')
test1
# Out:
#     Loan Identifier  Monthly Reporting Period  Channel  \
# 0         122752190                     22021        2
# 1         122752190                     32021        2
# 2         122752190                     42021        2
# 3         122752190                     52021        2
# 4         122752190                     62021        2
# 5         122752190                     72021        2
# 6         122752190                     82021        2
# 7         122752190                     92021        2
# 8         122752190                    102021        2
# 9         122752190                    112021        2
# 10        122752190                    122021        2
# 11        122752190                     12022        2
# 12        122752190                     22022        2
# 13        122752190                     32022        2
# 14        122752190                     42022        2
# 15        122752190                     52022        2
# 16        122752190                     62022        2
# 17        122752190                     72022        2
# 18        122752190                     82022        2
# 19        122752190                     92022        2
# 20        122752190                    102022        2
# 21        122752190                    112022        2
# 22        122752190                    122022        2
#
#     Original Interest Rate  Current Interest Rate  Original UPB  \
# 0                      3.0                    3.0      597000.0
# 1                      3.0                    3.0      597000.0
# 2                      3.0                    3.0      597000.0
# 3                      3.0                    3.0      597000.0
# 4                      3.0                    3.0      597000.0
# 5                      3.0                    3.0      597000.0
# 6                      3.0                    3.0      597000.0
# 7                      3.0                    3.0      597000.0
# 8                      3.0                    3.0      597000.0
# 9                      3.0                    3.0      597000.0
# 10                     3.0                    3.0      597000.0
# 11                     3.0                    3.0      597000.0
# 12                     3.0                    3.0      597000.0
# 13                     3.0                    3.0      597000.0
# 14                     3.0                    3.0      597000.0
# 15                     3.0                    3.0      597000.0
# 16                     3.0                    3.0      597000.0
# 17                     3.0                    3.0      597000.0
# 18                     3.0                    3.0      597000.0
# 19                     3.0                    3.0      597000.0
# 20                     3.0                    3.0      597000.0
# 21                     3.0                    3.0      597000.0
# 22                     3.0                    3.0      597000.0
#
#     Current Actual UPB  Original Loan Term  Origination Date  \
# 0            597000.00                 360             12021
# 1            596000.00                 360             12021
# 2            595000.00                 360             12021
# 3            594000.00                 360             12021
# 4            592000.00                 360             12021
# 5            591000.00                 360             12021
# 6            590000.00                 360             12021
# 7            589119.62                 360             12021
# 8            588004.21                 360             12021
# 9            586886.01                 360             12021
# 10           585765.02                 360             12021
# 11           584641.22                 360             12021
# 12           583514.61                 360             12021
# 13           582385.19                 360             12021
# 14           581252.94                 360             12021
# 15           580117.86                 360             12021
# 16           578979.94                 360             12021
# 17           577839.18                 360             12021
# 18           576695.57                 360             12021
# 19           575549.10                 360             12021
# 20           574399.76                 360             12021
# 21           573247.55                 360             12021
# 22           572092.46                 360             12021
#
#     First Payment Date  ...  Property Valuation Method  \
# 0                32021  ...                          3
# 1                32021  ...                          3
# 2                32021  ...                          3
# 3                32021  ...                          3
# 4                32021  ...                          3
# 5                32021  ...                          3
# 6                32021  ...                          3
# 7                32021  ...                          3
# 8                32021  ...                          3
# 9                32021  ...                          3
# 10               32021  ...                          3
# 11               32021  ...                          3
# 12               32021  ...                          3
# 13               32021  ...                          3
# 14               32021  ...                          3
# 15               32021  ...                          3
# 16               32021  ...                          3
# 17               32021  ...                          3
# 18               32021  ...                          3
# 19               32021  ...                          3
# 20               32021  ...                          3
# 21               32021  ...                          3
# 22               32021  ...                          3
#
#     High Balance Loan Indicator  Unemployment_rate  Divorce_rate  \
# 0                             1                5.3           2.5
# 1                             1                5.3           2.5
# 2                             1                5.3           2.5
# 3                             1                5.3           2.5
# 4                             1                5.3           2.5
# 5                             1                5.3           2.5
# 6                             1                5.3           2.5
# 7                             1                5.3           2.5
# 8                             1                5.3           2.5
# 9                             1                5.3           2.5
# 10                            1                5.3           2.5
# 11                            1                3.6           2.3
# 12                            1                3.6           2.3
# 13                            1                3.6           2.3
# 14                            1                3.6           2.3
# 15                            1                3.6           2.3
# 16                            1                3.6           2.3
# 17                            1                3.6           2.3
# 18                            1                3.6           2.3
# 19                            1                3.6           2.3
# 20                            1                3.6           2.3
# 21                            1                3.6           2.3
# 22                            1                3.6           2.3
#
#     Inflation_rate          EMI  UPB_diff  Interest_Component  Previous_UPB  \
# 0              1.7  2516.976081      0.00              1492.5     597000.00
# 1              2.6  2516.976081   1000.00              1492.5     597000.00
# 2              4.2  2516.976081   1000.00              1492.5     596000.00
# 3              5.0  2516.976081   1000.00              1492.5     595000.00
# 4              5.4  2516.976081   2000.00              1492.5     594000.00
# 5              5.4  2516.976081   1000.00              1492.5     592000.00
# 6              5.3  2516.976081   1000.00              1492.5     591000.00
# 7              5.4  2516.976081    880.38              1492.5     590000.00
# 8              6.2  2516.976081   1115.41              1492.5     589119.62
# 9              6.8  2516.976081   1118.20              1492.5     588004.21
# 10             7.0  2516.976081   1120.99              1492.5     586886.01
# 11             7.5  2516.976081   1123.80              1492.5     585765.02
# 12             7.9  2516.976081   1126.61              1492.5     584641.22
# 13             8.5  2516.976081   1129.42              1492.5     583514.61
# 14             8.3  2516.976081   1132.25              1492.5     582385.19
# 15             8.6  2516.976081   1135.08              1492.5     581252.94
# 16             9.1  2516.976081   1137.92              1492.5     580117.86
# 17             8.5  2516.976081   1140.76              1492.5     578979.94
# 18             8.3  2516.976081   1143.61              1492.5     577839.18
# 19             8.2  2516.976081   1146.47              1492.5     576695.57
# 20             7.7  2516.976081   1149.34              1492.5     575549.10
# 21             7.1  2516.976081   1152.21              1492.5     574399.76
# 22             6.5  2516.976081   1155.09              1492.5     573247.55
#
#     Remaining MFM
# 0             359
# 1             358
# 2             357
# 3             356
# 4             355
# 5             354
# 6             353
# 7             352
# 8             351
# 9             350
# 10            349
# 11            348
# 12            347
# 13            346
# 14            345
# 15            344
# 16            343
# 17            342
# 18            341
# 19            340
# 20            339
# 21            338
# 22            337
#
# [23 rows x 36 columns]

# %%
test1.drop(['Loan Identifier','EMI','UPB_diff','Interest_Component','Remaining Months To Maturity'], axis=1, inplace = True)
test1
# Out:
#     Monthly Reporting Period  Channel  Original Interest Rate  \
# 0                      22021        2                     3.0
# 1                      32021        2                     3.0
# 2                      42021        2                     3.0
# 3                      52021        2                     3.0
# 4                      62021        2                     3.0
# 5                      72021        2                     3.0
# 6                      82021        2                     3.0
# 7                      92021        2                     3.0
# 8                     102021        2                     3.0
# 9                     112021        2                     3.0
# 10                    122021        2                     3.0
# 11                     12022        2                     3.0
# 12                     22022        2                     3.0
# 13                     32022        2                     3.0
# 14                     42022        2                     3.0
# 15                     52022        2                     3.0
# 16                     62022        2                     3.0
# 17                     72022        2                     3.0
# 18                     82022        2                     3.0
# 19                     92022        2                     3.0
# 20                    102022        2                     3.0
# 21                    112022        2                     3.0
# 22                    122022        2                     3.0
#
#     Current Interest Rate  Original UPB  Current Actual UPB  \
# 0                     3.0      597000.0           597000.00
# 1                     3.0      597000.0           596000.00
# 2                     3.0      597000.0           595000.00
# 3                     3.0      597000.0           594000.00
# 4                     3.0      597000.0           592000.00
# 5                     3.0      597000.0           591000.00
# 6                     3.0      597000.0           590000.00
# 7                     3.0      597000.0           589119.62
# 8                     3.0      597000.0           588004.21
# 9                     3.0      597000.0           586886.01
# 10                    3.0      597000.0           585765.02
# 11                    3.0      597000.0           584641.22
# 12                    3.0      597000.0           583514.61
# 13                    3.0      597000.0           582385.19
# 14                    3.0      597000.0           581252.94
# 15                    3.0      597000.0           580117.86
# 16                    3.0      597000.0           578979.94
# 17                    3.0      597000.0           577839.18
# 18                    3.0      597000.0           576695.57
# 19                    3.0      597000.0           575549.10
# 20                    3.0      597000.0           574399.76
# 21                    3.0      597000.0           573247.55
# 22                    3.0      597000.0           572092.46
#
#     Original Loan Term  Origination Date  First Payment Date  \
# 0                  360             12021               32021
# 1                  360             12021               32021
# 2                  360             12021               32021
# 3                  360             12021               32021
# 4                  360             12021               32021
# 5                  360             12021               32021
# 6                  360             12021               32021
# 7                  360             12021               32021
# 8                  360             12021               32021
# 9                  360             12021               32021
# 10                 360             12021               32021
# 11                 360             12021               32021
# 12                 360             12021               32021
# 13                 360             12021               32021
# 14                 360             12021               32021
# 15                 360             12021               32021
# 16                 360             12021               32021
# 17                 360             12021               32021
# 18                 360             12021               32021
# 19                 360             12021               32021
# 20                 360             12021               32021
# 21                 360             12021               32021
# 22                 360             12021               32021
#
#     Original Loan to Value Ratio (LTV)  ...  Modification Flag  \
# 0                                   75  ...                0.0
# 1                                   75  ...                0.0
# 2                                   75  ...                0.0
# 3                                   75  ...                0.0
# 4                                   75  ...                0.0
# 5                                   75  ...                0.0
# 6                                   75  ...                0.0
# 7                                   75  ...                0.0
# 8                                   75  ...                0.0
# 9                                   75  ...                0.0
# 10                                  75  ...                0.0
# 11                                  75  ...                0.0
# 12                                  75  ...                0.0
# 13                                  75  ...                0.0
# 14                                  75  ...                0.0
# 15                                  75  ...                0.0
# 16                                  75  ...                0.0
# 17                                  75  ...                0.0
# 18                                  75  ...                0.0
# 19                                  75  ...                0.0
# 20                                  75  ...                0.0
# 21                                  75  ...                0.0
# 22                                  75  ...                0.0
#
#     Zero Balance Code  Special Eligibility Program  Property Valuation Method  \
# 0                 0.0                            0                          3
# 1                 0.0                            0                          3
# 2                 0.0                            0                          3
# 3                 0.0                            0                          3
# 4                 0.0                            0                          3
# 5                 0.0                            0                          3
# 6                 0.0                            0                          3
# 7                 0.0                            0                          3
# 8                 0.0                            0                          3
# 9                 0.0                            0                          3
# 10                0.0                            0                          3
# 11                0.0                            0                          3
# 12                0.0                            0                          3
# 13                0.0                            0                          3
# 14                0.0                            0                          3
# 15                0.0                            0                          3
# 16                0.0                            0                          3
# 17                0.0                            0                          3
# 18                0.0                            0                          3
# 19                0.0                            0                          3
# 20                0.0                            0                          3
# 21                0.0                            0                          3
# 22                0.0                            0                          3
#
#     High Balance Loan Indicator  Unemployment_rate  Divorce_rate  \
# 0                             1                5.3           2.5
# 1                             1                5.3           2.5
# 2                             1                5.3           2.5
# 3                             1                5.3           2.5
# 4                             1                5.3           2.5
# 5                             1                5.3           2.5
# 6                             1                5.3           2.5
# 7                             1                5.3           2.5
# 8                             1                5.3           2.5
# 9                             1                5.3           2.5
# 10                            1                5.3           2.5
# 11                            1                3.6           2.3
# 12                            1                3.6           2.3
# 13                            1                3.6           2.3
# 14                            1                3.6           2.3
# 15                            1                3.6           2.3
# 16                            1                3.6           2.3
# 17                            1                3.6           2.3
# 18                            1                3.6           2.3
# 19                            1                3.6           2.3
# 20                            1                3.6           2.3
# 21                            1                3.6           2.3
# 22                            1                3.6           2.3
#
#     Inflation_rate  Previous_UPB  Remaining MFM
# 0              1.7     597000.00            359
# 1              2.6     597000.00            358
# 2              4.2     596000.00            357
# 3              5.0     595000.00            356
# 4              5.4     594000.00            355
# 5              5.4     592000.00            354
# 6              5.3     591000.00            353
# 7              5.4     590000.00            352
# 8              6.2     589119.62            351
# 9              6.8     588004.21            350
# 10             7.0     586886.01            349
# 11             7.5     585765.02            348
# 12             7.9     584641.22            347
# 13             8.5     583514.61            346
# 14             8.3     582385.19            345
# 15             8.6     581252.94            344
# 16             9.1     580117.86            343
# 17             8.5     578979.94            342
# 18             8.3     577839.18            341
# 19             8.2     576695.57            340
# 20             7.7     575549.10            339
# 21             7.1     574399.76            338
# 22             6.5     573247.55            337
#
# [23 rows x 31 columns]

# %%
test1_x=test1.drop(['Current Actual UPB'],axis=1)

# %%
test1_y=test1['Current Actual UPB']

# %%
test1_x=scl.transform(test1_x)

# %%
pred=model.predict(test1_x)
# Out:
# 1/1 [==============================] - 0s 19ms/step

# %%
test1_y
# Out:
# 0     597000.00
# 1     596000.00
# 2     595000.00
# 3     594000.00
# 4     592000.00
# 5     591000.00
# 6     590000.00
# 7     589119.62
# 8     588004.21
# 9     586886.01
# 10    585765.02
# 11    584641.22
# 12    583514.61
# 13    582385.19
# 14    581252.94
# 15    580117.86
# 16    578979.94
# 17    577839.18
# 18    576695.57
# 19    575549.10
# 20    574399.76
# 21    573247.55
# 22    572092.46
# Name: Current Actual UPB, dtype: float64

# %%
pred
# Out:
# array([[596774.4 ],
#        [596653.2 ],
#        [595325.6 ],
#        [594324.7 ],
#        [593321.9 ],
#        [591314.1 ],
#        [590309.5 ],
#        [589305.75],
#        [588424.25],
#        [587306.2 ],
#        [586184.06],
#        [585077.25],
#        [583952.9 ],
#        [582826.2 ],
#        [581694.5 ],
#        [580561.4 ],
#        [579425.94],
#        [578283.75],
#        [577137.6 ],
#        [575989.06],
#        [574836.25],
#        [573680.2 ],
#        [572521.3 ]], dtype=float32)

# %%
mean_absolute_error(pred,test1_y)
# Out:
# 443.084673913054

# %%
for i in range(len(pred)):
    print(pred[i]-test1_y[i])
# Out:
# [-225.625]
# [653.1875]
# [325.625]
# [324.6875]
# [1321.875]
# [314.125]
# [309.5]
# [186.125]
# [420.0625]
# [420.1875]
# [419.0625]
# [436.]
# [438.25]
# [441.]
# [441.5625]
# [443.5]
# [446.]
# [444.5625]
# [442.0625]
# [439.9375]
# [436.5]
# [432.625]
# [428.875]
